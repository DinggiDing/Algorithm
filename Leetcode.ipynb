# %% [markdown]
# # **Two Sum**

# %% [markdown]
# Python

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        answer = []
        for i in range(len(nums)-1):
            for j in range(i+1, len(nums)):
                if nums[i] + nums[j] == target:
                    answer.append(i)
                    answer.append(j)
                    break

        return answer

# %% [markdown]
# Swift

# %%
class Solution {
    func twoSum(_ nums: [Int], _ target: Int) -> [Int] {
        var answer = [Int]()
        for i in 0..<nums.count-1 {
            for j in i+1..<nums.count {
                if nums[i] + nums[j] == target {
                    answer.append(i)
                    answer.append(j)
                    break
                }
            }
        }

        return answer
    }
}

# %% [markdown]
# # **Palindrome Number**

# %% [markdown]
# Python

# %%
class Solution:
    def isPalindrome(self, x: int) -> bool:
        a = str(x)
        n = len(a)//2 if len(a)%2==0 else len(a)//2+1
        answer = True

        for i in range(n):
            p = a[i]
            q = a[-(i+1)]
            if p!=q:
                answer = False

        return answer

# %% [markdown]
# Swift

# %%
class Solution {
    func isPalindrome(_ x: Int) -> Bool {
        let a = String(x)
        var answer = true

        var n = a.count%2==0 ? Int(a.count/2) : Int(a.count)/2 + 1

        for i in 0..<n {
            if a[a.index(a.startIndex, offsetBy: i)] != a[a.index(a.startIndex, offsetBy: a.count-i-1)] {
                answer = false
            }
        }
        return answer
    }
}

# %% [markdown]
# # **Roman to Integer**

# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        roman = {'I':1,'V':5,'X':10,'L':50,'C':100,'D':500,'M':1000,'IV':4,'IX':9,'XL':40,'XC':90,'CD':400,'CM':900}
        i = 0
        num = 0
        while i < len(s):
            if i+1<len(s) and s[i:i+2] in roman:
                num+=roman[s[i:i+2]]
                i+=2
            else:
                #print(i)
                num+=roman[s[i]]
                i+=1
        return num

# %%
class Solution {
    func romanToInt(_ s: String) -> Int {
        let roman: [String: Int] = ["I":1,"V":5,"X":10,"L":50,"C":100,"D":500,"M":1000,"IV":4,"IX":9,"XL":40,"XC":90,"CD":400,"CM":900]

        var i = 0
        var answer = 0
        let str = Array(s)

        while i<s.count {

            if i+1 < s.count && (roman[String(str[i]) + String(str[i+1])] != nil) {
                answer += roman[String(str[i]) + String(str[i+1])]!
                i += 2

            } else {
                answer += roman[String(str[i])]!
                i += 1
            }
        }

        return answer
    }
}

# %% [markdown]
# Swift에서 문자열을 배열로 전환하여 처리하는 것이 편리함
#
# Array(s)

# %% [markdown]
# # **Longest Common Prefix**

# %%
class Solution:
    def longestCommonPrefix(self, strs: List[str]) -> str:
        answer = ""

        for i in range(len(strs[0]), 0, -1):
            isit = 0
            for j in range(len(strs)-1):
                if strs[0][0:i] in strs[j+1][0:i]:
                    isit += 1
            if isit == len(strs)-1:
                answer = strs[0][0:i]
                break
        return answer

# %%
class Solution {
    func longestCommonPrefix(_ strs: [String]) -> String {

        let n = strs.count
        var answer : String = ""
        var sum = 0
        for i in 0..<strs[0].count {
            sum = 0
            for j in 1..<strs.count {
                if String(strs[j].prefix(strs[0].count - i)) == String(strs[0].prefix(strs[0].count - i)) {
                    sum += 1
                }
            }
            if sum == strs.count-1 {
                answer = String(strs[0].prefix(strs[0].count - i))
                break
            }
        }

        return answer
    }
}

# %% [markdown]
# # **Island Perimeter**

# %%
class Solution:
    def islandPerimeter(self, grid: List[List[int]]) -> int:

        from collections import deque

        answer = 0

        m = len(grid[0])
        n = len(grid)
        arr = [[-1 for _ in range(m)] for _ in range(n)]
        visited = [[False for _ in range(m)] for _ in range(n)]

        start = (0,0)
        is_for = False
        for i in range(n):
            if is_for:
                break
            for j in range(m):
                if grid[i][j]==1:
                    start = (j, i)
                    is_for = True
                    break

        print(start)
        queue = deque([])
        queue.append(start)
        visited[start[1]][start[0]] = True

        while queue:
            x, y = queue.popleft()

            dx = [1, -1, 0, 0]
            dy = [0, 0, 1, -1]

            cnt = 0
            for i in range(4):
                nx = x + dx[i]
                ny = y + dy[i]

                if 0<= nx <m and 0<= ny <n and grid[ny][nx]==1:
                    if visited[ny][nx]==False:
                        queue.append((nx, ny))
                        visited[ny][nx] = True
                else:
                    cnt += 1

            if cnt>0:
                arr[y][x] = cnt

        print(arr)
        for i in range(n):
            for j in range(m):
                if arr[i][j]>0:
                    answer += arr[i][j]

        return answer

# %% [markdown]
# # **Flood Fill**

# %%
class Solution {
    func floodFill(_ image: [[Int]], _ sr: Int, _ sc: Int, _ color: Int) -> [[Int]] {

        let m = image[0].count
        let n = image.count
        var visited = Array(repeating: Array(repeating: false, count: m), count: n)
        var queue = [(Int, Int)]()
        var arr = image

        let start = (sr, sc)
        let point_color = image[sr][sc]
        queue.append(start)
        visited[sr][sc] = true
        arr[sr][sc] = color

        while !queue.isEmpty {
            let new = queue.removeFirst()

            let dx = [1, -1, 0, 0]
            let dy = [0, 0, -1, 1]

            for i in 0..<4 {
                let nx = new.0 + dx[i]
                let ny = new.1 + dy[i]

                if 0 <= ny && ny < m && 0 <= nx && nx < n && image[nx][ny] == point_color && visited[nx][ny]==false {

                    queue.append((nx, ny))
                    visited[nx][ny] = true
                    arr[nx][ny] = color
                }
            }
        }

        return arr
    }
}

# %% [markdown]
# # **Climbing Stairs**
#
# DP 문제

# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        k = 0
        a = 1
        b = 2

        if n==1:
            b=a
            return b
        for i in range(n-2):
            k = b
            b += a
            a = k

        return b

# %% [markdown]
# # **Letter Combinations of a Phone Number**

# %%
class Solution:
    def letterCombinations(self, digits: str) -> List[str]:
        arr = ["abc", "def", "ghi", "jkl", "mno", "pqrs", "tuv", "wxyz"]
        answer = []


        def dfs(row: int, output: str):
            if row==len(digits):
                answer.append(output)
                return

            for i in range(len(arr[int(digits[row])-2])):
                dfs(row+1, output + arr[int(digits[row])-2][i])

        if len(digits)!=0:
            dfs(0, "")

        return answer

# %% [markdown]
# # **Remove Elements**

# %%
class Solution {
    func removeElement(_ nums: inout [Int], _ val: Int) -> Int {

        nums = nums.filter { $0 != val }.sorted(by: { $0 < $1 })

        let k = nums.count

        return k
    }
}

# %% [markdown]
# # **Length of Last Word**

# %%
class Solution {
    func lengthOfLastWord(_ s: String) -> Int {
        let arr = s.split(separator: " ")

        return arr.last!.count
    }
}

# %% [markdown]
# # **Reverse Words in a String**

# %%
class Solution {
    func reverseWords(_ s: String) -> String {
        let arr = s.split(separator: " ")

        var answer = arr.last!
        for i in 1..<arr.count {
            answer = answer + " " + arr[arr.count - i - 1]
        }

        return String(answer)
    }
}

# %% [markdown]
# # **Is Subsequence**

# %%
class Solution {
    func isSubsequence(_ s: String, _ t: String) -> Bool {
        let n1 = t.count
        let n2 = s.count

        var cnt = 0
        var answer = false

        if n2 == 0 {
            return true
        }

        for i in 0..<n1 {

            if t[t.index(t.startIndex, offsetBy: i)] == s[s.index(s.startIndex, offsetBy: cnt)] {
                cnt += 1
            }

            if cnt == n2 {
                answer = true
                break
            }
        }



        return answer
    }
}

# %% [markdown]
# # **Search a 2D Matrix**

# %%
class Solution {
    func searchMatrix(_ matrix: [[Int]], _ target: Int) -> Bool {
        let m = matrix[0].count
        let n = matrix.count

        var row = 0
        var answer = false
        for i in 0..<n {
            if matrix[i][0] <= target {
                row = i
            } else {
                break
            }
        }

        for i in 0..<m {
            if matrix[row][i] == target {
                answer = true
            }
        }

        return answer
    }
}

# %% [markdown]
# # **Find Peak Element**

# %%
class Solution {
    func findPeakElement(_ nums: [Int]) -> Int {

        // return nums.firstIndex(of: nums.max()!)!

        var left = 0
        var right = nums.count - 1

        while left < right {
            let mid = (left + right) / 2

            if nums[mid] < nums[mid + 1] {
                left = mid + 1
            } else {
                right  = mid
            }
        }

        return left
    }
}

# %% [markdown]
# # **House Robber**

# %%
class Solution {
    func rob(_ nums: [Int]) -> Int {
        var answer = Array(repeating: 0, count: nums.count)

        answer[0] = nums[0]
        if nums.count == 1{
            return answer[0]
        }
        answer[1] = max(answer[0], nums[1])
        if nums.count == 2 {
            return max(answer[0], answer[1])
        }

        var i = 2

        while true {
            if i == nums.count {
                break
            }
            answer[i] = max(answer[i-1], answer[i-2] + nums[i])


            i += 1

        }

        print(answer)

        return answer.last!
    }
}

# %% [markdown]
# guard 조건 else {}
# 조건이 false일때만 {} 실행

# %% [markdown]
# # **2997 Minimum Number of Operations to Make Array XOR equals to K**

# %%
class Solution:
    def minOperations(self, nums: List[int], k: int) -> int:

        answer = 0
        a = 0
        for i in nums:
            a ^= i

        a ^= k

        b = str(format(a, 'b'))     # 2진수 변환
        for i in range(len(b)):
            if b[i]=="1":
                answer += 1

        return answer

# %% [markdown]
# # **Search Insert Position**

# %%
class Solution:
    def searchInsert(self, nums: List[int], target: int) -> int:
        nums.append(target)
        nums.sort(key=lambda x: x)

        return nums.index(target)

# %% [markdown]
# # **Number of Wonderful Substring** : 다시풀기

# %%
class Solution:
  def wonderfulSubstrings(self, word: str) -> int:
    ans = 0
    prefix = 0  # the binary prefix
    count = [0] * 1024  # the binary prefix count
    count[0] = 1  # the empty string ""

    for c in word:
      prefix ^= 1 << ord(c) - ord('a')
      # All the letters occur even number of times.
      ans += count[prefix]
      # `c` occurs odd number of times.
      ans += sum(count[prefix ^ 1 << i] for i in range(10))
      count[prefix] += 1

    return ans

# %% [markdown]
# # **Reverse Prefix of Word**

# %%
class Solution:
    def reversePrefix(self, word: str, ch: str) -> str:

        stack = ""
        idx = -1

        for i in range(len(word)):
            if word[i] == ch:
                stack += word[i]
                idx = i+1
                break
            else:
                stack += word[i]

        if idx != -1:
            stackarr = list(stack)
            stackarr.reverse()
            stack = ''.join(stackarr)
            stack += word[idx:]
        else:
            stack = word

        return stack

# %% [markdown]
# # **Valid Sudoku**

# %%
class Solution:
    def isValidSudoku(self, board: List[List[str]]) -> bool:

        answer = True

        # row
        for i in range(9):

            visited = [False for _ in range(10)]

            for j in range(9):
                if board[i][j] != ".":
                    if visited[int(board[i][j])]==False:
                        visited[int(board[i][j])] = True
                    else:
                        answer = False


        # column
        for i in range(9):

            visited = [False for _ in range(10)]

            for j in range(9):
                if board[j][i] != ".":
                    if visited[int(board[j][i])]==False:
                        visited[int(board[j][i])] = True
                    else:
                        answer = False

        # 3*3
        for i in range(9):

            visited = [False for _ in range(10)]

            for j in range(9):
                a = (i // 3)*3 + j // 3
                b = (i % 3)*3 + j % 3
                if board[a][b] != ".":
                    if visited[int(board[a][b])]==False:
                        visited[int(board[a][b])] = True
                    else:
                        answer = False


        return answer

# %% [markdown]
# # **2441 Largest Positive Integer That**

# %%
class Solution:
    def findMaxK(self, nums: List[int]) -> int:

        answer = -1

        while True:
            if len(nums) == 0:
                break

            # print(nums.count)
            a = max(nums)
            if -a in nums:
                answer = a
                break
            else:
                del nums[nums.index(a)]

        return answer

# %% [markdown]
# # **1895 Largest Magic Square**

# %%
class Solution:
    def largestMagicSquare(self, grid: List[List[int]]) -> int:

        answer = 1
        def checksum(arr: List[List[int]]) -> bool:
            n = len(arr)

            p_set = set()
            for i in arr:
                p_set.add(sum(i))
            if len(p_set) != 1:
                return False

            q_set = set()
            for i in zip(*arr):
                q_set.add(sum(i))
            if len(q_set) != 1:
                return False

            if p_set != q_set:
                return False

            r_a = 0
            r_b = 0
            for i in range(n):
                r_a += arr[i][i]
                r_b += arr[i][n-1-i]
            if r_a != r_b:
                return False
            if r_a != list(p_set)[0]:
                return False

            print(p_set, q_set, r_a)

            return True

        cnt = min(len(grid), len(grid[0]))
        for k in range(cnt, 0, -1):
            for i in range(len(grid) - k + 1):
                for j in range(len(grid[0]) - k + 1):
                    if checksum([row[j:j+k] for row in grid[i:i+k]])==True:
                        answer = k
                        return answer

        return answer

# %% [markdown]
# zip 통한 2차원 배열 뒤집기

# %% [markdown]
# # **165 Compare Version Numbers**

# %%
class Solution:
    def compareVersion(self, version1: str, version2: str) -> int:

        answer = 0

        arr = version1.split('.')
        arr = list(map(int, arr))

        brr = version2.split('.')
        brr = list(map(int, brr))

        na = len(arr)
        nb = len(brr)

        if na < nb:
            for i in range(nb - na):
                arr.append(0)
        else:
            for i in range(na - nb):
                brr.append(0)

        for i in range(len(arr)):
            if arr[i] < brr[i]:
                answer = -1
                break
            if arr[i] > brr[i]:
                answer = 1
                break
            if arr[i] == brr[i] and i==len(arr)-1:
                answer = 0

        return answer

# %% [markdown]
# # **Boats to Save People**

# %%
class Solution:
    def numRescueBoats(self, people: List[int], limit: int) -> int:
        people.sort(key=lambda x: x)
        answer = 0

        i = 0
        j = len(people)-1

        while i <= j:
            if people[i] + people[j] <= limit:
                i += 1
            j -= 1
            answer += 1
            # print(i, j, answer)

        return answer

# %% [markdown]
# # **4 Median of Two Sorted Arrays**

# %%
class Solution:
    def findMedianSortedArrays(self, nums1: List[int], nums2: List[int]) -> float:
        num = nums1 + nums2
        num.sort(key=lambda x: x)

        answer = 0
        n = len(num)

        if n % 2 == 1:
            answer = float(num[n//2])
        else:
            answer = (num[n//2] + num[n//2 - 1]) / 2

        return answer

# %% [markdown]
# # **167 Two Sum 2 - Input Array Is Sorted**

# %%
class Solution:
    def twoSum(self, numbers: List[int], target: int) -> List[int]:
        answer = []

        # onoff = False
        # for i in range(len(numbers)):
        #     for j in range(i+1, len(numbers)):
        #         if numbers[i] + numbers[j] == target:
        #             answer.append(i+1)
        #             answer.append(j+1)
        #             onoff = True
        #             break
        #     if onoff:
        #         break

        i = 0
        j = len(numbers) - 1

        while i<=j:
            if numbers[i] + numbers[j] == target:
                answer.append(i+1)
                answer.append(j+1)
                break

            if numbers[i] + numbers[j] < target:
                i += 1
            else:
                j -= 1


        return answer

# %% [markdown]
# 이분탐색으로 while 하나만 쓰기!!

# %% [markdown]
# # **54 Spiral Matrix**

# %%
class Solution:
    def spiralOrder(self, matrix: List[List[int]]) -> List[int]:

        dx = [1, 0, -1, 0]
        dy = [0, 1, 0, -1]

        m = len(matrix[0])
        n = len(matrix)
        visited = [[False for _ in range(m)] for _ in range(n)]
        answer = []
        i = 0
        direct = 0
        x = 0
        y = 0
        visited[0][0] = True
        answer.append(matrix[y][x])
        while i<m*n-1:

            if direct == 4:
                direct = 0

            nx = x + dx[direct]
            ny = y + dy[direct]

            if 0 <= nx < m and 0 <= ny < n and visited[ny][nx]==False:
                x = nx
                y = ny
                visited[ny][nx] = True
                answer.append(matrix[ny][nx])
            else:
                direct += 1
                if direct == 4:
                    direct = 0
                nx = x + dx[direct]
                ny = y + dy[direct]
                x = nx
                y = ny
                visited[ny][nx] = True
                answer.append(matrix[ny][nx])

            i += 1

        return answer

# %% [markdown]
# # **205 Isomorphic Strings**

# %%
class Solution:
    def isIsomorphic(self, s: str, t: str) -> bool:

        sdict = {}
        sarr = []
        na = 0
        for i in s:
            if i in sdict:
                sarr.append(sdict[i])
            else:
                sdict[i] = na
                sarr.append(na)
            na += 1

        tdict = {}
        tarr = []
        nb = 0
        for i in t:
            if i in tdict:
                tarr.append(tdict[i])
            else:
                tdict[i] = nb
                tarr.append(nb)
            nb += 1


        return tarr == sarr

# %% [markdown]
# # **49 Group Anagrams**

# %%
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:

        arr = {}

        for s in strs:
            a = ''.join(sorted(s))

            if a in arr:
                arr[a].append(s)
            else:
                arr[a] = [s]

        return list(arr.values())

# %% [markdown]
# # **228 Summary Ranges**

# %%
class Solution:
    def summaryRanges(self, nums: List[int]) -> List[str]:
        answer = []
        if len(nums) == 0:
            return answer
        nums.append(nums[-1])
        n = len(nums)

        arr = []
        arr.append(nums[0])
        for i in range(1, n):
            if len(arr)==0:
                arr.append(nums[i])

            if arr[-1] == nums[i]-1:
                arr.append(nums[i])
            else:
                if len(arr) != 1:
                    sss = str(arr[0]) + "->" + str(arr[-1])
                    answer.append(sss)
                else:
                    sss = str(arr[0])
                    answer.append(sss)
                arr = []
                arr.append(nums[i])

        # print(answer)

        return answer

# %% [markdown]
# # **56 Merge Intervals**

# %%
class Solution:
    def merge(self, intervals: List[List[int]]) -> List[List[int]]:
        intervals.sort(key=lambda x: x[0])
        print(intervals)

        answer = []
        answer.append(intervals[0])
        for i in range(1, len(intervals)):
            if intervals[i][0] <= answer[-1][1]:
                answer[-1][1] = max(intervals[i][1], answer[-1][1])
            else:
                answer.append(intervals[i])

        return answer

# %% [markdown]
# # **200 Number of Islands**

# %%
class Solution:
    def numIslands(self, grid: List[List[str]]) -> int:

        m = len(grid[0])
        n = len(grid)
        visited = [[-1 for _ in range(m)] for _ in range(n)]
        cnt = 0

        from collections import deque

        for a in range(n):
            for b in range(m):
                if grid[a][b] == "1" and visited[a][b]==-1:
                    cnt += 1
                    queue = deque()
                    queue.append((b, a))
                    visited[a][b] = cnt

                    dx = [1, -1, 0, 0]
                    dy = [0, 0, 1, -1]

                    while queue:
                        x, y = queue.pop()

                        for i in range(4):
                            nx = x + dx[i]
                            ny = y + dy[i]

                            if 0<=nx<m and 0<=ny<n and grid[ny][nx]=="1" and visited[ny][nx]==-1:
                                queue.append((nx, ny))
                                visited[ny][nx] = cnt

        return cnt

# %% [markdown]
# # **77 Combinations**

# %%
class Solution:
    def combine(self, n: int, k: int) -> List[List[int]]:
        from itertools import combinations

        arr = [i for i in range(1, n+1)]
        answer = []
        for i in combinations(arr, k):
            answer.append(i)

        return answer

# %% [markdown]
# # **230 Kth Smallest Element in a BST**

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def kthSmallest(self, root: Optional[TreeNode], k: int) -> int:

        answer = []
        self.dfs(root, answer)
        return answer[k-1]


    def dfs(self, root, values):
        if root is None:
            return

        self.dfs(root.left, values)
        values.append(root.val)
        self.dfs(root.right, values)

# %% [markdown]
# # **20 Valid Parentheses**

# %%
class Solution:
    def isValid(self, s: str) -> bool:
        while len(s) > 0:
            l = len(s)
            s = s.replace('()', '').replace('{}', '').replace('[]', '')
            if l == len(s):
                return False
        return True

# %% [markdown]
# # **2816 Double a Number Represented as a LinkedList**

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def doubleIt(self, head: Optional[ListNode]) -> Optional[ListNode]:
        arr = []

        while True:
            if head == None:
                break
            arr.append(head.val)
            head = head.next

        arr = arr[::-1]
        print(arr)
        node = None
        q = 0
        for i in range(len(arr)):

            p = (arr[i]*2) % 10 + q
            if arr[i]*2 // 10 == 1:
                q = 1
            else:
                q = 0
            node = ListNode(p, node)
        if q == 1:
            node = ListNode(q, node)

        return node

# %% [markdown]
# # **506 Relative Ranks**

# %%
class Solution:
    def findRelativeRanks(self, score: List[int]) -> List[str]:
        arr = []

        s = sorted(score, key=lambda x: -x)

        for i in range(len(score)):
            b = ""
            a = s.index(score[i])
            if a==0:
                b = "Gold Medal"
            elif a==1:
                b = "Silver Medal"
            elif a==2:
                b = "Bronze Medal"
            else:
                b = str(a+1)
            arr.append(b)

        return arr

# %% [markdown]
# # **3075 Maximize Happiness of Selected Children**

# %%
class Solution:
    def maximumHappinessSum(self, happiness: List[int], k: int) -> int:
        happiness.sort(key=lambda x: -x)
        answer = 0

        for i in range(k):
            if happiness[i] - i > 0:
                answer += happiness[i] - i

            else:
                break

        return answer

# %% [markdown]
# # **786 K-th Smallest Prime Fraction**

# %%
class Solution:
    def kthSmallestPrimeFraction(self, arr: List[int], k: int) -> List[int]:

        from itertools import combinations
        answer = []
        dict = {}

        for i in combinations(arr, 2):
            answer.append(i[0]/ i[1])
            dict[i[0]/i[1]] = [i[0], i[1]]

        answer.sort(key=lambda x: x)

        return dict[answer[k-1]]

# %% [markdown]
# # **2373 Largest Local Values in a Matrix**

# %%
class Solution:
    def largestLocal(self, grid: List[List[int]]) -> List[List[int]]:

        def checkarr(arr: List[List[int]]) -> int:
            sum = 0
            for i in range(3):
                for j in range(3):
                    if sum < arr[i][j]:
                        sum =  arr[i][j]

            return sum

        import numpy as np

        arr = [[0 for _ in range(len(grid[0])-2)] for _ in range(len(grid)-2)]

        gridd = np.array(grid)
        for i in range(len(gridd[0]) - 2):
            for j in range(len(gridd) -2):
                arr[j][i] = checkarr(gridd[j:j+3,i:i+3])

        return arr

# %% [markdown]
# arrar = np.array( arr )
#
# arrar[0:2, 0:2]  : 슬라이싱

# %% [markdown]
# # **861 Score After Flipping Matrix**

# %%
class Solution:
    def matrixScore(self, grid: List[List[int]]) -> int:

        m = len(grid[0])
        n = len(grid)

        while True:
            # 1. All 1st column => 1
            # 2. half of 2nd ~ column => 1

            for i in range(n):
                if grid[i][0] == 0:
                    for j in range(m):
                        grid[i][j] ^= 1

            for i in range(1, m):
                cnt = 0
                for j in range(n):
                    if grid[j][i]==1:
                        cnt += 1

                if cnt < n/2:
                    for j in range(n):
                        grid[j][i] ^= 1

            break

        answer = 0
        for i in range(n):
            st = ""
            for j in range(m):
                st += str(grid[i][j])
            answer += int(st, 2)

        return answer

# %% [markdown]
# # **1219**
#
# dfs

# %%
class Solution:
    def getMaximumGold(self, grid: List[List[int]]) -> int:
        m = len(grid[0])
        n = len(grid)

        visited = [[False for _ in range(len(grid[0]))] for _ in range(len(grid))]
        dx = [1, -1, 0, 0]
        dy = [0, 0, 1, -1]

        arr = [0]
        def dfs(nx: int, ny: int, s: int):
            if arr[0] < s:
                arr[0] = s
            for i in range(4):
                x = nx + dx[i]
                y = ny + dy[i]

                if 0<= x <m and 0<= y <n and visited[y][x]==False and grid[y][x]!=0:
                    visited[y][x] = True
                    dfs(x, y, s+grid[y][x])
                    visited[y][x] = False

        for i in range(n):
            for j in range(m):
                if grid[i][j]>0:
                    visited[i][j] = True
                    dfs(j, i, grid[i][j])
                    visited[i][j] = False

        # dfs(1, 2, 0)

        return arr[0]

# %% [markdown]
# # **26**
#
# Array

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:

        dict = {}
        n = len(nums)
        i = 0
        while i<n:
            if nums[i] in dict:
                del nums[i]
                nums.append("_")
            elif nums[i] == "_":
                break
            else:
                dict[nums[i]] = 1
                i += 1

        print(nums)

        return i

# %% [markdown]
# # **3074**

# %%
class Solution:
    def minimumBoxes(self, apple: List[int], capacity: List[int]) -> int:

        cnt = sum(apple)
        capacity.sort(key=lambda x: -x)
        i = 0

        while cnt>0:
            if capacity[i]==0:
                break
            if cnt >= capacity[i]:
                cnt -= capacity[i]
                capacity[i]=0
                i += 1
            else:
                i += 1
                break

        print(cnt, capacity)

        return i

# %% [markdown]
# # **2331**
#
# tree

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def evaluateTree(self, root: Optional[TreeNode]) -> bool:
        return self.dfs(root)

    def dfs(self, root) -> bool:
        if root.val == 1:
            return True
        elif root.val == 2:
            return self.dfs(root.left) or self.dfs(root.right)
        elif root.val == 3:
            return self.dfs(root.left) and self.dfs(root.right)
        else:
            return False

# %% [markdown]
# # **139**
#
# DP

# %%
class Solution:
    def wordBreak(self, s: str, wordDict: List[str]) -> bool:

        print(max(map(len, wordDict)))

        n = len(s)
        dp = [False] * (n+1)
        max_n = max(map(len, wordDict))

        dp[0] = True

        for i in range(1, n+1):
            for j in range(i-1, max(i-max_n-1, -1), -1):
                if dp[j] and s[j:i] in wordDict:
                    dp[i] = True
                    break

        return dp[n]

# %% [markdown]
# # **300**
#
# DP

# %%
class Solution:
    def lengthOfLIS(self, nums: List[int]) -> int:

        n = len(nums)
        dp = [1] * n

        for i in range(n):
            for j in range(i):
                if nums[i] > nums[j]:
                    dp[i] = max(dp[i], dp[j]+1)

        return max(dp)

# %% [markdown]
# # **1325**
#
# Tree

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def removeLeafNodes(self, root: Optional[TreeNode], target: int) -> Optional[TreeNode]:
        if root.left:
            root.left = self.removeLeafNodes(root.left, target)
        if root.right:
            root.right = self.removeLeafNodes(root.right, target)

        if root.left == None and root.right == None and root.val == target:
            root = None
        return root

# %% [markdown]
# # **322**
#
# DP

# %%
class Solution:
    def coinChange(self, coins: List[int], amount: int) -> int:

        dp = [0] * (amount+1)
        MAX = float('inf')

        for i in range(1, amount+1):
            arr = [MAX]
            for j in coins:
                if (i-j) >= 0:
                    arr.append(dp[i-j])
            dp[i] = min(arr) + 1

        return dp[amount] if dp[amount]!=MAX else -1

# %% [markdown]
# # **64**
#
# DP

# %%
class Solution:
    def minPathSum(self, grid: List[List[int]]) -> int:

        m = len(grid[0])
        n = len(grid)

        dp = [[0 for _ in range(m+1)] for _ in range(n+1)]

        for i in range(1, m+1):
            dp[1][i] = grid[0][i-1] + dp[1][i-1]
        for i in range(1, n+1):
            dp[i][1] = grid[i-1][0] + dp[i-1][1]

        for i in range(2, m+1):
            for j in range(2, n+1):
                dp[j][i] = min(dp[j-1][i], dp[j][i-1]) + grid[j-1][i-1]

        return dp[n][m]

# %% [markdown]
# # **979**
#
# Tree

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    answer = 0
    def distributeCoins(self, root: Optional[TreeNode]) -> int:

        def check(root):
            if not root:
                return 0

            left = check(root.left)
            right = check(root.right)
            self.answer += abs(left) + abs(right)
            return root.val + left + right - 1
        check(root)

        return self.answer

# %% [markdown]
# # **63**
#
# DP

# %%
class Solution:
    def uniquePathsWithObstacles(self, obstacleGrid: List[List[int]]) -> int:
        m = len(obstacleGrid[0])
        n = len(obstacleGrid)

        dp = [[0 for _ in range(m)] for _ in range(n)]

        # initial setting
        for i in range(m):
            if obstacleGrid[0][i] == 0:
                dp[0][i] = 1
            else:
                dp[0][i] = 0
                break
        for i in range(n):
            if obstacleGrid[i][0] == 0:
                dp[i][0] = 1
            else:
                dp[i][0] = 0
                break

        for i in range(1, n):
            for j in range(1, m):
                p = 0
                q = 0
                if obstacleGrid[i][j] == 1:
                    dp[i][j] = 0
                else:
                    if obstacleGrid[i-1][j] == 0:
                        p = dp[i-1][j]
                    if obstacleGrid[i][j-1] == 0:
                        q = dp[i][j-1]
                    dp[i][j] = p + q

        if obstacleGrid[n-1][m-1]==1 or obstacleGrid[0][0]==1:
            return 0
        return dp[n-1][m-1]

# %% [markdown]
# # **1863**
#
# 순열 조합

# %%
class Solution:
    def subsetXORSum(self, nums: List[int]) -> int:

        from itertools import combinations

        sum = 0

        for k in range(1, len(nums)+1):
            for i in combinations(nums, k):
                a = 0
                for j in i:
                    a ^= j
                sum += a

        return sum

# %% [markdown]
# # **78**
#
# 순열, 조합

# %%
class Solution:
    def subsets(self, nums: List[int]) -> List[List[int]]:

        from itertools import combinations
        answer = []

        for k in range(len(nums)+1):
            for i in combinations(nums, k):
                answer.append(i)

        return answer

# %% [markdown]
# # **131**
#
# DP

# %%
class Solution:
    def partition(self, s: str) -> List[List[str]]:

        if not s:
            return [[]]

        answer = []
        for i in range(1, len(s)+1):
            if s[:i] == s[:i][::-1]:
                for j in self.partition(s[i:]):
                    answer.append([s[:i]] + j)
                    print(answer, [s[:i]], j)

        return answer

# %% [markdown]
# # **2597**
#
# 백트래킹

# %%
class Solution:
    def beautifulSubsets(self, nums: List[int], k: int) -> int:

        from itertools import combinations
        arr = []
        answer = []
        sum = 0

        for i in range(len(nums)):
            for j in range(i, len(nums)):
                if k == abs(nums[i] - nums[j]):
                    arr.append([nums[i], nums[j]])

        # print(arr)

        for k in range(1, len(nums)+1):
            for i in combinations(nums, k):
                onoff = True

                # if list(i) in arr:
                #     onoff = False
                for a in arr:
                    # print(set(a), set(list(i)))
                    if set(a) <= set(list(i)):
                        onoff = False
                        break

                if onoff:
                    # answer.append(list(i))
                    sum += 1

        # print(answer)
        return sum

# %% [markdown]
# 순열, 조합 -> 효율은 좋진 않지만 통과는 함...

# %%
class Solution:
    def beautifulSubsets(self, nums: List[int], k: int) -> int:

        freq = {}
        def f(i: int) -> int:
            if i == len(nums): # base case
                return 1
            result = f(i + 1) # nums[i] not taken
            if not nums[i] - k in freq and not nums[i] + k in freq: # check if we can take nums[i]
                freq[nums[i]] = freq.get(nums[i], 0) + 1
                result += f(i + 1) # nums[i] taken
                freq[nums[i]] -= 1
                if freq[nums[i]] == 0:
                    del freq[nums[i]]
            return result
        return f(0) - 1 # -1 for empty subset

# %% [markdown]
# # **909**
#
# BFS

# %%
class Solution:
    def snakesAndLadders(self, board: List[List[int]]) -> int:
        arr = [0]
        n = len(board)
        from collections import deque
        visited = [-1 for _ in range(n*n+1)]

        for i in range(1, n+1):
            if i % 2 == 1:
                arr += board[n-i]
            else:
                arr += board[n-i][::-1]

        queue = deque()
        queue.append((1, 0))
        # visited[1] = 0

        while queue:
            new, cnt = queue.popleft()

            if arr[new] != -1:
                new = arr[new]

            if new == n*n:
                return cnt

            for i in range(6):
                nw = i+1 + new
                if nw <= n*n and visited[nw] == -1:
                    visited[nw] = cnt+1
                    queue.append((nw, cnt + 1))

        return -1

# %% [markdown]
# # **140**
#
# DP, DFS

# %%
class Solution:
    def wordBreak(self, s: str, wordDict: List[str]) -> List[str]:
        dic = {}

        for word in wordDict:
            dic[word] = dic.get(word, 0) + 1

        answer = []
        self.dfs(s, wordDict, "", answer)

        return answer

    def dfs(self, s: str, wordDict, memo, ans):

        if not s:
            ans.append(memo[1:])

            return ans

        for i in range(len(wordDict)):
            cnt = len(wordDict[i])

            if cnt <= len(s):
                if s[:cnt] == wordDict[i]:
                    self.dfs(s[cnt:], wordDict, memo + ' ' + wordDict[i], ans)

# %% [markdown]
# # **552**
#
# DP

# %%
class Solution:
    def checkRecord(self, n: int) -> int:
        m = 1000000007
        if n <= 2:
            A = [0 for _ in range(3)]
            P = [0 for _ in range(3)]
            L = [0 for _ in range(3)]
        else:
            A = [0 for _ in range(n)]
            P = [0 for _ in range(n)]
            L = [0 for _ in range(n)]

        P[0] = 1
        L[0], L[1] = 1,3
        A[0], A[1] = 1,2
        A[2] = 4

        if n==1: return 3

        for i in range(1, n):
            A[i-1] %= m
            P[i-1] %= m
            L[i-1] %= m

            P[i] = ((A[i-1] + P[i-1]) % m + L[i-1]) % m

            if i>1:
                L[i] = ((A[i - 1] + P[i - 1]) % m + (A[i - 2] + P[i - 2]) % m) % m
            if i>2:
                A[i] = ((A[i - 1] + A[i - 2]) % m + A[i - 3]) % m

        return ((A[n - 1] % m + P[n - 1] % m) % m + L[n - 1] % m) % m

# %% [markdown]
# # **1608**
#
# 구현

# %%
class Solution:
    def specialArray(self, nums: List[int]) -> int:

        nums.sort(reverse=True)
        nums.append(0)
        answer = -1

        for i in range(len(nums)):
            if nums[i] >= i+1 and nums[i+1] < i+1:
                answer = i+1

        return answer

# %% [markdown]
# # **1208**
#
# sliding window

# %%
class Solution:
    def equalSubstring(self, s: str, t: str, maxCost: int) -> int:

        answer = 0
        arr = []

        for i in range(len(s)):
            arr.append(abs(ord(s[i]) - ord(t[i])))

        cnt = 0
        j = 0
        for i in range(len(arr)):
            cnt += arr[i]

            while cnt > maxCost:
                cnt -= arr[j]
                j += 1

            answer = max(answer, i - j + 1)

        return answer

# %% [markdown]
# # **1404**
#
# 구현

# %%
class Solution:
    def numSteps(self, s: str) -> int:
        n = int(s, 2)
        cnt = [0]

        def dfs(n: int):
            if n == 1:
                return

            if n % 2 == 0:
                cnt[0] += 1
                dfs(n//2)
            else:
                cnt[0] += 1
                dfs(n+1)

        dfs(n)

        return cnt[0]

# %% [markdown]
# # **260**
#
# 딕셔너리

# %%
class Solution:
    def singleNumber(self, nums: List[int]) -> List[int]:
        dic = {}
        arr = []

        for i in nums:
            dic[i] = dic.get(i, 0) + 1

        for i in dic.keys():
            if dic[i] == 1:
                arr.append(i)

        # print(dic, arr)

        return arr
